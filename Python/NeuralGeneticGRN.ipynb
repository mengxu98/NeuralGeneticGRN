# %%
pip install pygad

# %%
import pygad
import numpy

function_inputs = [4,-2,3.5,5,-11,-4.7]
desired_output = 44

def fitness_func(ga_instance, solution, solution_idx):
    output = numpy.sum(solution*function_inputs)
    fitness = 1.0 / (numpy.abs(output - desired_output) + 0.000001)
    return fitness

fitness_function = fitness_func

def on_start(ga_instance):
    print("on_start()")

def on_fitness(ga_instance, population_fitness):
    print("on_fitness()")

def on_parents(ga_instance, selected_parents):
    print("on_parents()")

def on_crossover(ga_instance, offspring_crossover):
    print("on_crossover()")

def on_mutation(ga_instance, offspring_mutation):
    print("on_mutation()")

def on_generation(ga_instance):
    print("on_generation()")

def on_stop(ga_instance, last_population_fitness):
    print("on_stop()")

ga_instance = pygad.GA(num_generations=3,
                       num_parents_mating=5,
                       fitness_func=fitness_function,
                       sol_per_pop=10,
                       num_genes=len(function_inputs),
                       on_start=on_start,
                       on_fitness=on_fitness,
                       on_parents=on_parents,
                       on_crossover=on_crossover,
                       on_mutation=on_mutation,
                       on_generation=on_generation,
                       on_stop=on_stop)

ga_instance.run()

# %%
import numpy
import pygad
import pygad.nn
import pygad.gann

def fitness_func(ga_instance, solution, sol_idx):
    global GANN_instance, data_inputs, data_outputs

    predictions = pygad.nn.predict(last_layer=GANN_instance.population_networks[sol_idx],
                                   data_inputs=data_inputs)
    correct_predictions = numpy.where(predictions == data_outputs)[0].size
    solution_fitness = (correct_predictions/data_outputs.size)*100

    return solution_fitness

def callback_generation(ga_instance):
    global GANN_instance, last_fitness

    population_matrices = pygad.gann.population_as_matrices(population_networks=GANN_instance.population_networks, 
                                                            population_vectors=ga_instance.population)

    GANN_instance.update_population_trained_weights(population_trained_weights=population_matrices)

    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))

    last_fitness = ga_instance.best_solution()[1].copy()

# Holds the fitness value of the previous generation.
last_fitness = 0

# Preparing the NumPy array of the inputs.
data_inputs = numpy.array([[1, 1],
                           [1, 0],
                           [0, 1],
                           [0, 0]])

# Preparing the NumPy array of the outputs.
data_outputs = numpy.array([0, 
                            1, 
                            1, 
                            0])

# The length of the input vector for each sample (i.e. number of neurons in the input layer).
num_inputs = data_inputs.shape[1]
# The number of neurons in the output layer (i.e. number of classes).
num_classes = 2

# Creating an initial population of neural networks. The return of the initial_population() function holds references to the networks, not their weights. Using such references, the weights of all networks can be fetched.
num_solutions = 6 # A solution or a network can be used interchangeably.
GANN_instance = pygad.gann.GANN(num_solutions=num_solutions,
                                num_neurons_input=num_inputs,
                                num_neurons_hidden_layers=[2],
                                num_neurons_output=num_classes,
                                hidden_activations=["relu"],
                                output_activation="softmax")

# population does not hold the numerical weights of the network instead it holds a list of references to each last layer of each network (i.e. solution) in the population. A solution or a network can be used interchangeably.
# If there is a population with 3 solutions (i.e. networks), then the population is a list with 3 elements. Each element is a reference to the last layer of each network. Using such a reference, all details of the network can be accessed.
population_vectors = pygad.gann.population_as_vectors(population_networks=GANN_instance.population_networks)

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter. This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters. If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
initial_population = population_vectors.copy()

num_parents_mating = 4 # Number of solutions to be selected as parents in the mating pool.

num_generations = 500 # Number of generations.

mutation_percent_genes = 5 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists.

parent_selection_type = "sss" # Type of parent selection.

crossover_type = "single_point" # Type of the crossover operator.

mutation_type = "random" # Type of the mutation operator.

keep_parents = 1 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

init_range_low = -2
init_range_high = 5

ga_instance = pygad.GA(num_generations=num_generations, 
                       num_parents_mating=num_parents_mating, 
                       initial_population=initial_population,
                       fitness_func=fitness_func,
                       mutation_percent_genes=mutation_percent_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       keep_parents=keep_parents,
                       on_generation=callback_generation)

ga_instance.run()

# After the generations complete, some plots are showed that summarize how the outputs/fitness values evolve over generations.
ga_instance.plot_fitness()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# Predicting the outputs of the data using the best solution.
predictions = pygad.nn.predict(last_layer=GANN_instance.population_networks[solution_idx],
                               data_inputs=data_inputs)
print("Predictions of the trained network : {predictions}".format(predictions=predictions))

# Calculating some statistics
num_wrong = numpy.where(predictions != data_outputs)[0]
num_correct = data_outputs.size - num_wrong.size
accuracy = 100 * (num_correct/data_outputs.size)
print("Number of correct classifications : {num_correct}.".format(num_correct=num_correct))
print("Number of wrong classifications : {num_wrong}.".format(num_wrong=num_wrong.size))
print("Classification accuracy : {accuracy}.".format(accuracy=accuracy))
# Out:
# c:\Python311\Lib\site-packages\pygad\pygad.py:748: UserWarning: The percentage of genes to mutate (mutation_percent_genes=5) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   warnings.warn(f"The percentage of genes to mutate (mutation_percent_genes={mutation_percent_genes}) resutled in selecting ({mutation_num_genes}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.")
# Generation = 1
# Fitness    = 75.0
# Change     = 75.0
# Generation = 2
# Fitness    = 75.0
# Change     = 0.0
# Generation = 3
# Fitness    = 75.0
# Change     = 0.0
# Generation = 4
# Fitness    = 75.0
# Change     = 0.0
# Generation = 5
# Fitness    = 75.0
# Change     = 0.0
# Generation = 6
# Fitness    = 75.0
# Change     = 0.0
# Generation = 7
# Fitness    = 100.0
# Change     = 25.0
# Generation = 8
# Fitness    = 100.0
# Change     = 0.0
# Generation = 9
# Fitness    = 100.0
# Change     = 0.0
# Generation = 10
# Fitness    = 100.0
# Change     = 0.0
# Generation = 11
# Fitness    = 100.0
# Change     = 0.0
# Generation = 12
# Fitness    = 100.0
# Change     = 0.0
# Generation = 13
# Fitness    = 100.0
# Change     = 0.0
# Generation = 14
# Fitness    = 100.0
# Change     = 0.0
# Generation = 15
# Fitness    = 100.0
# Change     = 0.0
# Generation = 16
# Fitness    = 100.0
# Change     = 0.0
# Generation = 17
# Fitness    = 100.0
# Change     = 0.0
# Generation = 18
# Fitness    = 100.0
# Change     = 0.0
# Generation = 19
# Fitness    = 100.0
# Change     = 0.0
# Generation = 20
# Fitness    = 100.0
# Change     = 0.0
# Generation = 21
# Fitness    = 100.0
# Change     = 0.0
# Generation = 22
# Fitness    = 100.0
# Change     = 0.0
# Generation = 23
# Fitness    = 100.0
# Change     = 0.0
# Generation = 24
# Fitness    = 100.0
# Change     = 0.0
# Generation = 25
# Fitness    = 100.0
# Change     = 0.0
# Generation = 26
# Fitness    = 100.0
# Change     = 0.0
# Generation = 27
# Fitness    = 100.0
# Change     = 0.0
# Generation = 28
# Fitness    = 100.0
# Change     = 0.0
# Generation = 29
# Fitness    = 100.0
# Change     = 0.0
# Generation = 30
# Fitness    = 100.0
# Change     = 0.0
# Generation = 31
# Fitness    = 100.0
# Change     = 0.0
# Generation = 32
# Fitness    = 100.0
# Change     = 0.0
# Generation = 33
# Fitness    = 100.0
# Change     = 0.0
# Generation = 34
# Fitness    = 100.0
# Change     = 0.0
# Generation = 35
# Fitness    = 100.0
# Change     = 0.0
# Generation = 36
# Fitness    = 100.0
# Change     = 0.0
# Generation = 37
# Fitness    = 100.0
# Change     = 0.0
# Generation = 38
# Fitness    = 100.0
# Change     = 0.0
# Generation = 39
# Fitness    = 100.0
# Change     = 0.0
# Generation = 40
# Fitness    = 100.0
# Change     = 0.0
# Generation = 41
# Fitness    = 100.0
# Change     = 0.0
# Generation = 42
# Fitness    = 100.0
# Change     = 0.0
# Generation = 43
# Fitness    = 100.0
# Change     = 0.0
# Generation = 44
# Fitness    = 100.0
# Change     = 0.0
# Generation = 45
# Fitness    = 100.0
# Change     = 0.0
# Generation = 46
# Fitness    = 100.0
# Change     = 0.0
# Generation = 47
# Fitness    = 100.0
# Change     = 0.0
# Generation = 48
# Fitness    = 100.0
# Change     = 0.0
# Generation = 49
# Fitness    = 100.0
# Change     = 0.0
# Generation = 50
# Fitness    = 100.0
# Change     = 0.0
# Generation = 51
# Fitness    = 100.0
# Change     = 0.0
# Generation = 52
# Fitness    = 100.0
# Change     = 0.0
# Generation = 53
# Fitness    = 100.0
# Change     = 0.0
# Generation = 54
# Fitness    = 100.0
# Change     = 0.0
# Generation = 55
# Fitness    = 100.0
# Change     = 0.0
# Generation = 56
# Fitness    = 100.0
# Change     = 0.0
# Generation = 57
# Fitness    = 100.0
# Change     = 0.0
# Generation = 58
# Fitness    = 100.0
# Change     = 0.0
# Generation = 59
# Fitness    = 100.0
# Change     = 0.0
# Generation = 60
# Fitness    = 100.0
# Change     = 0.0
# Generation = 61
# Fitness    = 100.0
# Change     = 0.0
# Generation = 62
# Fitness    = 100.0
# Change     = 0.0
# Generation = 63
# Fitness    = 100.0
# Change     = 0.0
# Generation = 64
# Fitness    = 100.0
# Change     = 0.0
# Generation = 65
# Fitness    = 100.0
# Change     = 0.0
# Generation = 66
# Fitness    = 100.0
# Change     = 0.0
# Generation = 67
# Fitness    = 100.0
# Change     = 0.0
# Generation = 68
# Fitness    = 100.0
# Change     = 0.0
# Generation = 69
# Fitness    = 100.0
# Change     = 0.0
# Generation = 70
# Fitness    = 100.0
# Change     = 0.0
# Generation = 71
# Fitness    = 100.0
# Change     = 0.0
# Generation = 72
# Fitness    = 100.0
# Change     = 0.0
# Generation = 73
# Fitness    = 100.0
# Change     = 0.0
# Generation = 74
# Fitness    = 100.0
# Change     = 0.0
# Generation = 75
# Fitness    = 100.0
# Change     = 0.0
# Generation = 76
# Fitness    = 100.0
# Change     = 0.0
# Generation = 77
# Fitness    = 100.0
# Change     = 0.0
# Generation = 78
# Fitness    = 100.0
# Change     = 0.0
# Generation = 79
# Fitness    = 100.0
# Change     = 0.0
# Generation = 80
# Fitness    = 100.0
# Change     = 0.0
# Generation = 81
# Fitness    = 100.0
# Change     = 0.0
# Generation = 82
# Fitness    = 100.0
# Change     = 0.0
# Generation = 83
# Fitness    = 100.0
# Change     = 0.0
# Generation = 84
# Fitness    = 100.0
# Change     = 0.0
# Generation = 85
# Fitness    = 100.0
# Change     = 0.0
# Generation = 86
# Fitness    = 100.0
# Change     = 0.0
# Generation = 87
# Fitness    = 100.0
# Change     = 0.0
# Generation = 88
# Fitness    = 100.0
# Change     = 0.0
# Generation = 89
# Fitness    = 100.0
# Change     = 0.0
# Generation = 90
# Fitness    = 100.0
# Change     = 0.0
# Generation = 91
# Fitness    = 100.0
# Change     = 0.0
# Generation = 92
# Fitness    = 100.0
# Change     = 0.0
# Generation = 93
# Fitness    = 100.0
# Change     = 0.0
# Generation = 94
# Fitness    = 100.0
# Change     = 0.0
# Generation = 95
# Fitness    = 100.0
# Change     = 0.0
# Generation = 96
# Fitness    = 100.0
# Change     = 0.0
# Generation = 97
# Fitness    = 100.0
# Change     = 0.0
# Generation = 98
# Fitness    = 100.0
# Change     = 0.0
# Generation = 99
# Fitness    = 100.0
# Change     = 0.0
# Generation = 100
# Fitness    = 100.0
# Change     = 0.0
# Generation = 101
# Fitness    = 100.0
# Change     = 0.0
# Generation = 102
# Fitness    = 100.0
# Change     = 0.0
# Generation = 103
# Fitness    = 100.0
# Change     = 0.0
# Generation = 104
# Fitness    = 100.0
# Change     = 0.0
# Generation = 105
# Fitness    = 100.0
# Change     = 0.0
# Generation = 106
# Fitness    = 100.0
# Change     = 0.0
# Generation = 107
# Fitness    = 100.0
# Change     = 0.0
# Generation = 108
# Fitness    = 100.0
# Change     = 0.0
# Generation = 109
# Fitness    = 100.0
# Change     = 0.0
# Generation = 110
# Fitness    = 100.0
# Change     = 0.0
# Generation = 111
# Fitness    = 100.0
# Change     = 0.0
# Generation = 112
# Fitness    = 100.0
# Change     = 0.0
# Generation = 113
# Fitness    = 100.0
# Change     = 0.0
# Generation = 114
# Fitness    = 100.0
# Change     = 0.0
# Generation = 115
# Fitness    = 100.0
# Change     = 0.0
# Generation = 116
# Fitness    = 100.0
# Change     = 0.0
# Generation = 117
# Fitness    = 100.0
# Change     = 0.0
# Generation = 118
# Fitness    = 100.0
# Change     = 0.0
# Generation = 119
# Fitness    = 100.0
# Change     = 0.0
# Generation = 120
# Fitness    = 100.0
# Change     = 0.0
# Generation = 121
# Fitness    = 100.0
# Change     = 0.0
# Generation = 122
# Fitness    = 100.0
# Change     = 0.0
# Generation = 123
# Fitness    = 100.0
# Change     = 0.0
# Generation = 124
# Fitness    = 100.0
# Change     = 0.0
# Generation = 125
# Fitness    = 100.0
# Change     = 0.0
# Generation = 126
# Fitness    = 100.0
# Change     = 0.0
# Generation = 127
# Fitness    = 100.0
# Change     = 0.0
# Generation = 128
# Fitness    = 100.0
# Change     = 0.0
# Generation = 129
# Fitness    = 100.0
# Change     = 0.0
# Generation = 130
# Fitness    = 100.0
# Change     = 0.0
# Generation = 131
# Fitness    = 100.0
# Change     = 0.0
# Generation = 132
# Fitness    = 100.0
# Change     = 0.0
# Generation = 133
# Fitness    = 100.0
# Change     = 0.0
# Generation = 134
# Fitness    = 100.0
# Change     = 0.0
# Generation = 135
# Fitness    = 100.0
# Change     = 0.0
# Generation = 136
# Fitness    = 100.0
# Change     = 0.0
# Generation = 137
# Fitness    = 100.0
# Change     = 0.0
# Generation = 138
# Fitness    = 100.0
# Change     = 0.0
# Generation = 139
# Fitness    = 100.0
# Change     = 0.0
# Generation = 140
# Fitness    = 100.0
# Change     = 0.0
# Generation = 141
# Fitness    = 100.0
# Change     = 0.0
# Generation = 142
# Fitness    = 100.0
# Change     = 0.0
# Generation = 143
# Fitness    = 100.0
# Change     = 0.0
# Generation = 144
# Fitness    = 100.0
# Change     = 0.0
# Generation = 145
# Fitness    = 100.0
# Change     = 0.0
# Generation = 146
# Fitness    = 100.0
# Change     = 0.0
# Generation = 147
# Fitness    = 100.0
# Change     = 0.0
# Generation = 148
# Fitness    = 100.0
# Change     = 0.0
# Generation = 149
# Fitness    = 100.0
# Change     = 0.0
# Generation = 150
# Fitness    = 100.0
# Change     = 0.0
# Generation = 151
# Fitness    = 100.0
# Change     = 0.0
# Generation = 152
# Fitness    = 100.0
# Change     = 0.0
# Generation = 153
# Fitness    = 100.0
# Change     = 0.0
# Generation = 154
# Fitness    = 100.0
# Change     = 0.0
# Generation = 155
# Fitness    = 100.0
# Change     = 0.0
# Generation = 156
# Fitness    = 100.0
# Change     = 0.0
# Generation = 157
# Fitness    = 100.0
# Change     = 0.0
# Generation = 158
# Fitness    = 100.0
# Change     = 0.0
# Generation = 159
# Fitness    = 100.0
# Change     = 0.0
# Generation = 160
# Fitness    = 100.0
# Change     = 0.0
# Generation = 161
# Fitness    = 100.0
# Change     = 0.0
# Generation = 162
# Fitness    = 100.0
# Change     = 0.0
# Generation = 163
# Fitness    = 100.0
# Change     = 0.0
# Generation = 164
# Fitness    = 100.0
# Change     = 0.0
# Generation = 165
# Fitness    = 100.0
# Change     = 0.0
# Generation = 166
# Fitness    = 100.0
# Change     = 0.0
# Generation = 167
# Fitness    = 100.0
# Change     = 0.0
# Generation = 168
# Fitness    = 100.0
# Change     = 0.0
# Generation = 169
# Fitness    = 100.0
# Change     = 0.0
# Generation = 170
# Fitness    = 100.0
# Change     = 0.0
# Generation = 171
# Fitness    = 100.0
# Change     = 0.0
# Generation = 172
# Fitness    = 100.0
# Change     = 0.0
# Generation = 173
# Fitness    = 100.0
# Change     = 0.0
# Generation = 174
# Fitness    = 100.0
# Change     = 0.0
# Generation = 175
# Fitness    = 100.0
# Change     = 0.0
# Generation = 176
# Fitness    = 100.0
# Change     = 0.0
# Generation = 177
# Fitness    = 100.0
# Change     = 0.0
# Generation = 178
# Fitness    = 100.0
# Change     = 0.0
# Generation = 179
# Fitness    = 100.0
# Change     = 0.0
# Generation = 180
# Fitness    = 100.0
# Change     = 0.0
# Generation = 181
# Fitness    = 100.0
# Change     = 0.0
# Generation = 182
# Fitness    = 100.0
# Change     = 0.0
# Generation = 183
# Fitness    = 100.0
# Change     = 0.0
# Generation = 184
# Fitness    = 100.0
# Change     = 0.0
# Generation = 185
# Fitness    = 100.0
# Change     = 0.0
# Generation = 186
# Fitness    = 100.0
# Change     = 0.0
# Generation = 187
# Fitness    = 100.0
# Change     = 0.0
# Generation = 188
# Fitness    = 100.0
# Change     = 0.0
# Generation = 189
# Fitness    = 100.0
# Change     = 0.0
# Generation = 190
# Fitness    = 100.0
# Change     = 0.0
# Generation = 191
# Fitness    = 100.0
# Change     = 0.0
# Generation = 192
# Fitness    = 100.0
# Change     = 0.0
# Generation = 193
# Fitness    = 100.0
# Change     = 0.0
# Generation = 194
# Fitness    = 100.0
# Change     = 0.0
# Generation = 195
# Fitness    = 100.0
# Change     = 0.0
# Generation = 196
# Fitness    = 100.0
# Change     = 0.0
# Generation = 197
# Fitness    = 100.0
# Change     = 0.0
# Generation = 198
# Fitness    = 100.0
# Change     = 0.0
# Generation = 199
# Fitness    = 100.0
# Change     = 0.0
# Generation = 200
# Fitness    = 100.0
# Change     = 0.0
# Generation = 201
# Fitness    = 100.0
# Change     = 0.0
# Generation = 202
# Fitness    = 100.0
# Change     = 0.0
# Generation = 203
# Fitness    = 100.0
# Change     = 0.0
# Generation = 204
# Fitness    = 100.0
# Change     = 0.0
# Generation = 205
# Fitness    = 100.0
# Change     = 0.0
# Generation = 206
# Fitness    = 100.0
# Change     = 0.0
# Generation = 207
# Fitness    = 100.0
# Change     = 0.0
# Generation = 208
# Fitness    = 100.0
# Change     = 0.0
# Generation = 209
# Fitness    = 100.0
# Change     = 0.0
# Generation = 210
# Fitness    = 100.0
# Change     = 0.0
# Generation = 211
# Fitness    = 100.0
# Change     = 0.0
# Generation = 212
# Fitness    = 100.0
# Change     = 0.0
# Generation = 213
# Fitness    = 100.0
# Change     = 0.0
# Generation = 214
# Fitness    = 100.0
# Change     = 0.0
# Generation = 215
# Fitness    = 100.0
# Change     = 0.0
# Generation = 216
# Fitness    = 100.0
# Change     = 0.0
# Generation = 217
# Fitness    = 100.0
# Change     = 0.0
# Generation = 218
# Fitness    = 100.0
# Change     = 0.0
# Generation = 219
# Fitness    = 100.0
# Change     = 0.0
# Generation = 220
# Fitness    = 100.0
# Change     = 0.0
# Generation = 221
# Fitness    = 100.0
# Change     = 0.0
# Generation = 222
# Fitness    = 100.0
# Change     = 0.0
# Generation = 223
# Fitness    = 100.0
# Change     = 0.0
# Generation = 224
# Fitness    = 100.0
# Change     = 0.0
# Generation = 225
# Fitness    = 100.0
# Change     = 0.0
# Generation = 226
# Fitness    = 100.0
# Change     = 0.0
# Generation = 227
# Fitness    = 100.0
# Change     = 0.0
# Generation = 228
# Fitness    = 100.0
# Change     = 0.0
# Generation = 229
# Fitness    = 100.0
# Change     = 0.0
# Generation = 230
# Fitness    = 100.0
# Change     = 0.0
# Generation = 231
# Fitness    = 100.0
# Change     = 0.0
# Generation = 232
# Fitness    = 100.0
# Change     = 0.0
# Generation = 233
# Fitness    = 100.0
# Change     = 0.0
# Generation = 234
# Fitness    = 100.0
# Change     = 0.0
# Generation = 235
# Fitness    = 100.0
# Change     = 0.0
# Generation = 236
# Fitness    = 100.0
# Change     = 0.0
# Generation = 237
# Fitness    = 100.0
# Change     = 0.0
# Generation = 238
# Fitness    = 100.0
# Change     = 0.0
# Generation = 239
# Fitness    = 100.0
# Change     = 0.0
# Generation = 240
# Fitness    = 100.0
# Change     = 0.0
# Generation = 241
# Fitness    = 100.0
# Change     = 0.0
# Generation = 242
# Fitness    = 100.0
# Change     = 0.0
# Generation = 243
# Fitness    = 100.0
# Change     = 0.0
# Generation = 244
# Fitness    = 100.0
# Change     = 0.0
# Generation = 245
# Fitness    = 100.0
# Change     = 0.0
# Generation = 246
# Fitness    = 100.0
# Change     = 0.0
# Generation = 247
# Fitness    = 100.0
# Change     = 0.0
# Generation = 248
# Fitness    = 100.0
# Change     = 0.0
# Generation = 249
# Fitness    = 100.0
# Change     = 0.0
# Generation = 250
# Fitness    = 100.0
# Change     = 0.0
# Generation = 251
# Fitness    = 100.0
# Change     = 0.0
# Generation = 252
# Fitness    = 100.0
# Change     = 0.0
# Generation = 253
# Fitness    = 100.0
# Change     = 0.0
# Generation = 254
# Fitness    = 100.0
# Change     = 0.0
# Generation = 255
# Fitness    = 100.0
# Change     = 0.0
# Generation = 256
# Fitness    = 100.0
# Change     = 0.0
# Generation = 257
# Fitness    = 100.0
# Change     = 0.0
# Generation = 258
# Fitness    = 100.0
# Change     = 0.0
# Generation = 259
# Fitness    = 100.0
# Change     = 0.0
# Generation = 260
# Fitness    = 100.0
# Change     = 0.0
# Generation = 261
# Fitness    = 100.0
# Change     = 0.0
# Generation = 262
# Fitness    = 100.0
# Change     = 0.0
# Generation = 263
# Fitness    = 100.0
# Change     = 0.0
# Generation = 264
# Fitness    = 100.0
# Change     = 0.0
# Generation = 265
# Fitness    = 100.0
# Change     = 0.0
# Generation = 266
# Fitness    = 100.0
# Change     = 0.0
# Generation = 267
# Fitness    = 100.0
# Change     = 0.0
# Generation = 268
# Fitness    = 100.0
# Change     = 0.0
# Generation = 269
# Fitness    = 100.0
# Change     = 0.0
# Generation = 270
# Fitness    = 100.0
# Change     = 0.0
# Generation = 271
# Fitness    = 100.0
# Change     = 0.0
# Generation = 272
# Fitness    = 100.0
# Change     = 0.0
# Generation = 273
# Fitness    = 100.0
# Change     = 0.0
# Generation = 274
# Fitness    = 100.0
# Change     = 0.0
# Generation = 275
# Fitness    = 100.0
# Change     = 0.0
# Generation = 276
# Fitness    = 100.0
# Change     = 0.0
# Generation = 277
# Fitness    = 100.0
# Change     = 0.0
# Generation = 278
# Fitness    = 100.0
# Change     = 0.0
# Generation = 279
# Fitness    = 100.0
# Change     = 0.0
# Generation = 280
# Fitness    = 100.0
# Change     = 0.0
# Generation = 281
# Fitness    = 100.0
# Change     = 0.0
# Generation = 282
# Fitness    = 100.0
# Change     = 0.0
# Generation = 283
# Fitness    = 100.0
# Change     = 0.0
# Generation = 284
# Fitness    = 100.0
# Change     = 0.0
# Generation = 285
# Fitness    = 100.0
# Change     = 0.0
# Generation = 286
# Fitness    = 100.0
# Change     = 0.0
# Generation = 287
# Fitness    = 100.0
# Change     = 0.0
# Generation = 288
# Fitness    = 100.0
# Change     = 0.0
# Generation = 289
# Fitness    = 100.0
# Change     = 0.0
# Generation = 290
# Fitness    = 100.0
# Change     = 0.0
# Generation = 291
# Fitness    = 100.0
# Change     = 0.0
# Generation = 292
# Fitness    = 100.0
# Change     = 0.0
# Generation = 293
# Fitness    = 100.0
# Change     = 0.0
# Generation = 294
# Fitness    = 100.0
# Change     = 0.0
# Generation = 295
# Fitness    = 100.0
# Change     = 0.0
# Generation = 296
# Fitness    = 100.0
# Change     = 0.0
# Generation = 297
# Fitness    = 100.0
# Change     = 0.0
# Generation = 298
# Fitness    = 100.0
# Change     = 0.0
# Generation = 299
# Fitness    = 100.0
# Change     = 0.0
# Generation = 300
# Fitness    = 100.0
# Change     = 0.0
# Generation = 301
# Fitness    = 100.0
# Change     = 0.0
# Generation = 302
# Fitness    = 100.0
# Change     = 0.0
# Generation = 303
# Fitness    = 100.0
# Change     = 0.0
# Generation = 304
# Fitness    = 100.0
# Change     = 0.0
# Generation = 305
# Fitness    = 100.0
# Change     = 0.0
# Generation = 306
# Fitness    = 100.0
# Change     = 0.0
# Generation = 307
# Fitness    = 100.0
# Change     = 0.0
# Generation = 308
# Fitness    = 100.0
# Change     = 0.0
# Generation = 309
# Fitness    = 100.0
# Change     = 0.0
# Generation = 310
# Fitness    = 100.0
# Change     = 0.0
# Generation = 311
# Fitness    = 100.0
# Change     = 0.0
# Generation = 312
# Fitness    = 100.0
# Change     = 0.0
# Generation = 313
# Fitness    = 100.0
# Change     = 0.0
# Generation = 314
# Fitness    = 100.0
# Change     = 0.0
# Generation = 315
# Fitness    = 100.0
# Change     = 0.0
# Generation = 316
# Fitness    = 100.0
# Change     = 0.0
# Generation = 317
# Fitness    = 100.0
# Change     = 0.0
# Generation = 318
# Fitness    = 100.0
# Change     = 0.0
# Generation = 319
# Fitness    = 100.0
# Change     = 0.0
# Generation = 320
# Fitness    = 100.0
# Change     = 0.0
# Generation = 321
# Fitness    = 100.0
# Change     = 0.0
# Generation = 322
# Fitness    = 100.0
# Change     = 0.0
# Generation = 323
# Fitness    = 100.0
# Change     = 0.0
# Generation = 324
# Fitness    = 100.0
# Change     = 0.0
# Generation = 325
# Fitness    = 100.0
# Change     = 0.0
# Generation = 326
# Fitness    = 100.0
# Change     = 0.0
# Generation = 327
# Fitness    = 100.0
# Change     = 0.0
# Generation = 328
# Fitness    = 100.0
# Change     = 0.0
# Generation = 329
# Fitness    = 100.0
# Change     = 0.0
# Generation = 330
# Fitness    = 100.0
# Change     = 0.0
# Generation = 331
# Fitness    = 100.0
# Change     = 0.0
# Generation = 332
# Fitness    = 100.0
# Change     = 0.0
# Generation = 333
# Fitness    = 100.0
# Change     = 0.0
# Generation = 334
# Fitness    = 100.0
# Change     = 0.0
# Generation = 335
# Fitness    = 100.0
# Change     = 0.0
# Generation = 336
# Fitness    = 100.0
# Change     = 0.0
# Generation = 337
# Fitness    = 100.0
# Change     = 0.0
# Generation = 338
# Fitness    = 100.0
# Change     = 0.0
# Generation = 339
# Fitness    = 100.0
# Change     = 0.0
# Generation = 340
# Fitness    = 100.0
# Change     = 0.0
# Generation = 341
# Fitness    = 100.0
# Change     = 0.0
# Generation = 342
# Fitness    = 100.0
# Change     = 0.0
# Generation = 343
# Fitness    = 100.0
# Change     = 0.0
# Generation = 344
# Fitness    = 100.0
# Change     = 0.0
# Generation = 345
# Fitness    = 100.0
# Change     = 0.0
# Generation = 346
# Fitness    = 100.0
# Change     = 0.0
# Generation = 347
# Fitness    = 100.0
# Change     = 0.0
# Generation = 348
# Fitness    = 100.0
# Change     = 0.0
# Generation = 349
# Fitness    = 100.0
# Change     = 0.0
# Generation = 350
# Fitness    = 100.0
# Change     = 0.0
# Generation = 351
# Fitness    = 100.0
# Change     = 0.0
# Generation = 352
# Fitness    = 100.0
# Change     = 0.0
# Generation = 353
# Fitness    = 100.0
# Change     = 0.0
# Generation = 354
# Fitness    = 100.0
# Change     = 0.0
# Generation = 355
# Fitness    = 100.0
# Change     = 0.0
# Generation = 356
# Fitness    = 100.0
# Change     = 0.0
# Generation = 357
# Fitness    = 100.0
# Change     = 0.0
# Generation = 358
# Fitness    = 100.0
# Change     = 0.0
# Generation = 359
# Fitness    = 100.0
# Change     = 0.0
# Generation = 360
# Fitness    = 100.0
# Change     = 0.0
# Generation = 361
# Fitness    = 100.0
# Change     = 0.0
# Generation = 362
# Fitness    = 100.0
# Change     = 0.0
# Generation = 363
# Fitness    = 100.0
# Change     = 0.0
# Generation = 364
# Fitness    = 100.0
# Change     = 0.0
# Generation = 365
# Fitness    = 100.0
# Change     = 0.0
# Generation = 366
# Fitness    = 100.0
# Change     = 0.0
# Generation = 367
# Fitness    = 100.0
# Change     = 0.0
# Generation = 368
# Fitness    = 100.0
# Change     = 0.0
# Generation = 369
# Fitness    = 100.0
# Change     = 0.0
# Generation = 370
# Fitness    = 100.0
# Change     = 0.0
# Generation = 371
# Fitness    = 100.0
# Change     = 0.0
# Generation = 372
# Fitness    = 100.0
# Change     = 0.0
# Generation = 373
# Fitness    = 100.0
# Change     = 0.0
# Generation = 374
# Fitness    = 100.0
# Change     = 0.0
# Generation = 375
# Fitness    = 100.0
# Change     = 0.0
# Generation = 376
# Fitness    = 100.0
# Change     = 0.0
# Generation = 377
# Fitness    = 100.0
# Change     = 0.0
# Generation = 378
# Fitness    = 100.0
# Change     = 0.0
# Generation = 379
# Fitness    = 100.0
# Change     = 0.0
# Generation = 380
# Fitness    = 100.0
# Change     = 0.0
# Generation = 381
# Fitness    = 100.0
# Change     = 0.0
# Generation = 382
# Fitness    = 100.0
# Change     = 0.0
# Generation = 383
# Fitness    = 100.0
# Change     = 0.0
# Generation = 384
# Fitness    = 100.0
# Change     = 0.0
# Generation = 385
# Fitness    = 100.0
# Change     = 0.0
# Generation = 386
# Fitness    = 100.0
# Change     = 0.0
# Generation = 387
# Fitness    = 100.0
# Change     = 0.0
# Generation = 388
# Fitness    = 100.0
# Change     = 0.0
# Generation = 389
# Fitness    = 100.0
# Change     = 0.0
# Generation = 390
# Fitness    = 100.0
# Change     = 0.0
# Generation = 391
# Fitness    = 100.0
# Change     = 0.0
# Generation = 392
# Fitness    = 100.0
# Change     = 0.0
# Generation = 393
# Fitness    = 100.0
# Change     = 0.0
# Generation = 394
# Fitness    = 100.0
# Change     = 0.0
# Generation = 395
# Fitness    = 100.0
# Change     = 0.0
# Generation = 396
# Fitness    = 100.0
# Change     = 0.0
# Generation = 397
# Fitness    = 100.0
# Change     = 0.0
# Generation = 398
# Fitness    = 100.0
# Change     = 0.0
# Generation = 399
# Fitness    = 100.0
# Change     = 0.0
# Generation = 400
# Fitness    = 100.0
# Change     = 0.0
# Generation = 401
# Fitness    = 100.0
# Change     = 0.0
# Generation = 402
# Fitness    = 100.0
# Change     = 0.0
# Generation = 403
# Fitness    = 100.0
# Change     = 0.0
# Generation = 404
# Fitness    = 100.0
# Change     = 0.0
# Generation = 405
# Fitness    = 100.0
# Change     = 0.0
# Generation = 406
# Fitness    = 100.0
# Change     = 0.0
# Generation = 407
# Fitness    = 100.0
# Change     = 0.0
# Generation = 408
# Fitness    = 100.0
# Change     = 0.0
# Generation = 409
# Fitness    = 100.0
# Change     = 0.0
# Generation = 410
# Fitness    = 100.0
# Change     = 0.0
# Generation = 411
# Fitness    = 100.0
# Change     = 0.0
# Generation = 412
# Fitness    = 100.0
# Change     = 0.0
# Generation = 413
# Fitness    = 100.0
# Change     = 0.0
# Generation = 414
# Fitness    = 100.0
# Change     = 0.0
# Generation = 415
# Fitness    = 100.0
# Change     = 0.0
# Generation = 416
# Fitness    = 100.0
# Change     = 0.0
# Generation = 417
# Fitness    = 100.0
# Change     = 0.0
# Generation = 418
# Fitness    = 100.0
# Change     = 0.0
# Generation = 419
# Fitness    = 100.0
# Change     = 0.0
# Generation = 420
# Fitness    = 100.0
# Change     = 0.0
# Generation = 421
# Fitness    = 100.0
# Change     = 0.0
# Generation = 422
# Fitness    = 100.0
# Change     = 0.0
# Generation = 423
# Fitness    = 100.0
# Change     = 0.0
# Generation = 424
# Fitness    = 100.0
# Change     = 0.0
# Generation = 425
# Fitness    = 100.0
# Change     = 0.0
# Generation = 426
# Fitness    = 100.0
# Change     = 0.0
# Generation = 427
# Fitness    = 100.0
# Change     = 0.0
# Generation = 428
# Fitness    = 100.0
# Change     = 0.0
# Generation = 429
# Fitness    = 100.0
# Change     = 0.0
# Generation = 430
# Fitness    = 100.0
# Change     = 0.0
# Generation = 431
# Fitness    = 100.0
# Change     = 0.0
# Generation = 432
# Fitness    = 100.0
# Change     = 0.0
# Generation = 433
# Fitness    = 100.0
# Change     = 0.0
# Generation = 434
# Fitness    = 100.0
# Change     = 0.0
# Generation = 435
# Fitness    = 100.0
# Change     = 0.0
# Generation = 436
# Fitness    = 100.0
# Change     = 0.0
# Generation = 437
# Fitness    = 100.0
# Change     = 0.0
# Generation = 438
# Fitness    = 100.0
# Change     = 0.0
# Generation = 439
# Fitness    = 100.0
# Change     = 0.0
# Generation = 440
# Fitness    = 100.0
# Change     = 0.0
# Generation = 441
# Fitness    = 100.0
# Change     = 0.0
# Generation = 442
# Fitness    = 100.0
# Change     = 0.0
# Generation = 443
# Fitness    = 100.0
# Change     = 0.0
# Generation = 444
# Fitness    = 100.0
# Change     = 0.0
# Generation = 445
# Fitness    = 100.0
# Change     = 0.0
# Generation = 446
# Fitness    = 100.0
# Change     = 0.0
# Generation = 447
# Fitness    = 100.0
# Change     = 0.0
# Generation = 448
# Fitness    = 100.0
# Change     = 0.0
# Generation = 449
# Fitness    = 100.0
# Change     = 0.0
# Generation = 450
# Fitness    = 100.0
# Change     = 0.0
# Generation = 451
# Fitness    = 100.0
# Change     = 0.0
# Generation = 452
# Fitness    = 100.0
# Change     = 0.0
# Generation = 453
# Fitness    = 100.0
# Change     = 0.0
# Generation = 454
# Fitness    = 100.0
# Change     = 0.0
# Generation = 455
# Fitness    = 100.0
# Change     = 0.0
# Generation = 456
# Fitness    = 100.0
# Change     = 0.0
# Generation = 457
# Fitness    = 100.0
# Change     = 0.0
# Generation = 458
# Fitness    = 100.0
# Change     = 0.0
# Generation = 459
# Fitness    = 100.0
# Change     = 0.0
# Generation = 460
# Fitness    = 100.0
# Change     = 0.0
# Generation = 461
# Fitness    = 100.0
# Change     = 0.0
# Generation = 462
# Fitness    = 100.0
# Change     = 0.0
# Generation = 463
# Fitness    = 100.0
# Change     = 0.0
# Generation = 464
# Fitness    = 100.0
# Change     = 0.0
# Generation = 465
# Fitness    = 100.0
# Change     = 0.0
# Generation = 466
# Fitness    = 100.0
# Change     = 0.0
# Generation = 467
# Fitness    = 100.0
# Change     = 0.0
# Generation = 468
# Fitness    = 100.0
# Change     = 0.0
# Generation = 469
# Fitness    = 100.0
# Change     = 0.0
# Generation = 470
# Fitness    = 100.0
# Change     = 0.0
# Generation = 471
# Fitness    = 100.0
# Change     = 0.0
# Generation = 472
# Fitness    = 100.0
# Change     = 0.0
# Generation = 473
# Fitness    = 100.0
# Change     = 0.0
# Generation = 474
# Fitness    = 100.0
# Change     = 0.0
# Generation = 475
# Fitness    = 100.0
# Change     = 0.0
# Generation = 476
# Fitness    = 100.0
# Change     = 0.0
# Generation = 477
# Fitness    = 100.0
# Change     = 0.0
# Generation = 478
# Fitness    = 100.0
# Change     = 0.0
# Generation = 479
# Fitness    = 100.0
# Change     = 0.0
# Generation = 480
# Fitness    = 100.0
# Change     = 0.0
# Generation = 481
# Fitness    = 100.0
# Change     = 0.0
# Generation = 482
# Fitness    = 100.0
# Change     = 0.0
# Generation = 483
# Fitness    = 100.0
# Change     = 0.0
# Generation = 484
# Fitness    = 100.0
# Change     = 0.0
# Generation = 485
# Fitness    = 100.0
# Change     = 0.0
# Generation = 486
# Fitness    = 100.0
# Change     = 0.0
# Generation = 487
# Fitness    = 100.0
# Change     = 0.0
# Generation = 488
# Fitness    = 100.0
# Change     = 0.0
# Generation = 489
# Fitness    = 100.0
# Change     = 0.0
# Generation = 490
# Fitness    = 100.0
# Change     = 0.0
# Generation = 491
# Fitness    = 100.0
# Change     = 0.0
# Generation = 492
# Fitness    = 100.0
# Change     = 0.0
# Generation = 493
# Fitness    = 100.0
# Change     = 0.0
# Generation = 494
# Fitness    = 100.0
# Change     = 0.0
# Generation = 495
# Fitness    = 100.0
# Change     = 0.0
# Generation = 496
# Fitness    = 100.0
# Change     = 0.0
# Generation = 497
# Fitness    = 100.0
# Change     = 0.0
# Generation = 498
# Fitness    = 100.0
# Change     = 0.0
# Generation = 499
# Fitness    = 100.0
# Change     = 0.0
# Generation = 500
# Fitness    = 100.0
# Change     = 0.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Parameters of the best solution : [ 7.95562416  3.88135796 -2.08217097  4.14100904 -4.93377445 -1.44876031
#   3.46579671 -1.43154841]
# Fitness value of the best solution = 100.0
# Index of the best solution : 0
# Best fitness value reached after 7 generations.
# Predictions of the trained network : [0, 1, 1, 0]
# Number of correct classifications : 4.
# Number of wrong classifications : 0.
# Classification accuracy : 100.0.

# %% [markdown]
# For regression

# %%
import numpy
import pygad
import pygad.nn
import pygad.gann

def fitness_func(ga_instance, solution, sol_idx):
    global GANN_instance, data_inputs, data_outputs

    predictions = pygad.nn.predict(last_layer=GANN_instance.population_networks[sol_idx],
                                   data_inputs=data_inputs, problem_type="regression")
    solution_fitness = 1.0/numpy.mean(numpy.abs(predictions - data_outputs))

    return solution_fitness

def callback_generation(ga_instance):
    global GANN_instance, last_fitness

    population_matrices = pygad.gann.population_as_matrices(population_networks=GANN_instance.population_networks, 
                                                            population_vectors=ga_instance.population)

    GANN_instance.update_population_trained_weights(population_trained_weights=population_matrices)

    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution(pop_fitness=ga_instance.last_generation_fitness)[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution(pop_fitness=ga_instance.last_generation_fitness)[1] - last_fitness))

    last_fitness = ga_instance.best_solution(pop_fitness=ga_instance.last_generation_fitness)[1].copy()

# Holds the fitness value of the previous generation.
last_fitness = 0

# Preparing the NumPy array of the inputs.
data_inputs = numpy.array([[2, 5, -3, 0.1],
                           [8, 15, 20, 13]])

# Preparing the NumPy array of the outputs.
data_outputs = numpy.array([[0.1, 0.2],
                            [1.8, 1.5]])

# The length of the input vector for each sample (i.e. number of neurons in the input layer).
num_inputs = data_inputs.shape[1]

# Creating an initial population of neural networks. The return of the initial_population() function holds references to the networks, not their weights. Using such references, the weights of all networks can be fetched.
num_solutions = 6 # A solution or a network can be used interchangeably.
GANN_instance = pygad.gann.GANN(num_solutions=num_solutions,
                                num_neurons_input=num_inputs,
                                num_neurons_hidden_layers=[2],
                                num_neurons_output=2,
                                hidden_activations=["relu"],
                                output_activation="None")

# population does not hold the numerical weights of the network instead it holds a list of references to each last layer of each network (i.e. solution) in the population. A solution or a network can be used interchangeably.
# If there is a population with 3 solutions (i.e. networks), then the population is a list with 3 elements. Each element is a reference to the last layer of each network. Using such a reference, all details of the network can be accessed.
population_vectors = pygad.gann.population_as_vectors(population_networks=GANN_instance.population_networks)

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter. This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters. If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
initial_population = population_vectors.copy()

num_parents_mating = 4 # Number of solutions to be selected as parents in the mating pool.

num_generations = 500 # Number of generations.

mutation_percent_genes = 5 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists.

parent_selection_type = "sss" # Type of parent selection.

crossover_type = "single_point" # Type of the crossover operator.

mutation_type = "random" # Type of the mutation operator.

keep_parents = 1 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

init_range_low = -1
init_range_high = 1

ga_instance = pygad.GA(num_generations=num_generations, 
                       num_parents_mating=num_parents_mating, 
                       initial_population=initial_population,
                       fitness_func=fitness_func,
                       mutation_percent_genes=mutation_percent_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       keep_parents=keep_parents,
                       on_generation=callback_generation)

ga_instance.run()

# After the generations complete, some plots are showed that summarize how the outputs/fitness values evolve over generations.
ga_instance.plot_fitness()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution(pop_fitness=ga_instance.last_generation_fitness)
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# Predicting the outputs of the data using the best solution.
predictions = pygad.nn.predict(last_layer=GANN_instance.population_networks[solution_idx],
                               data_inputs=data_inputs,
                               problem_type="regression")
print("Predictions of the trained network : {predictions}".format(predictions=predictions))

# Calculating some statistics
abs_error = numpy.mean(numpy.abs(predictions - data_outputs))
print("Absolute error : {abs_error}.".format(abs_error=abs_error))
# Out:
# c:\Python311\Lib\site-packages\pygad\pygad.py:748: UserWarning: The percentage of genes to mutate (mutation_percent_genes=5) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   warnings.warn(f"The percentage of genes to mutate (mutation_percent_genes={mutation_percent_genes}) resutled in selecting ({mutation_num_genes}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.")
# Generation = 1
# Fitness    = 1.1566928173710835
# Change     = 1.1566928173710835
# Generation = 2
# Fitness    = 1.8782275595395763
# Change     = 0.7215347421684928
# Generation = 3
# Fitness    = 2.8338241820023797
# Change     = 0.9555966224628034
# Generation = 4
# Fitness    = 2.9771908961887648
# Change     = 0.14336671418638502
# Generation = 5
# Fitness    = 2.9771908961887648
# Change     = 0.0
# Generation = 6
# Fitness    = 2.9771908961887648
# Change     = 0.0
# Generation = 7
# Fitness    = 2.9771908961887648
# Change     = 0.0
# Generation = 8
# Fitness    = 3.622020435952301
# Change     = 0.6448295397635362
# Generation = 9
# Fitness    = 3.7346605677646525
# Change     = 0.11264013181235155
# Generation = 10
# Fitness    = 3.7346605677646525
# Change     = 0.0
# Generation = 11
# Fitness    = 4.657226708784553
# Change     = 0.9225661410199009
# Generation = 12
# Fitness    = 4.657226708784553
# Change     = 0.0
# Generation = 13
# Fitness    = 4.657226708784553
# Change     = 0.0
# Generation = 14
# Fitness    = 4.657226708784553
# Change     = 0.0
# Generation = 15
# Fitness    = 4.657226708784553
# Change     = 0.0
# Generation = 16
# Fitness    = 4.657226708784553
# Change     = 0.0
# Generation = 17
# Fitness    = 5.088998507638252
# Change     = 0.4317717988536982
# Generation = 18
# Fitness    = 5.088998507638252
# Change     = 0.0
# Generation = 19
# Fitness    = 5.088998507638252
# Change     = 0.0
# Generation = 20
# Fitness    = 5.336515291869203
# Change     = 0.24751678423095136
# Generation = 21
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 22
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 23
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 24
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 25
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 26
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 27
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 28
# Fitness    = 5.336515291869203
# Change     = 0.0
# Generation = 29
# Fitness    = 9.527089102356943
# Change     = 4.19057381048774
# Generation = 30
# Fitness    = 9.527089102356943
# Change     = 0.0
# Generation = 31
# Fitness    = 9.527089102356943
# Change     = 0.0
# Generation = 32
# Fitness    = 9.527089102356943
# Change     = 0.0
# Generation = 33
# Fitness    = 9.527089102356943
# Change     = 0.0
# Generation = 34
# Fitness    = 9.527089102356943
# Change     = 0.0
# Generation = 35
# Fitness    = 9.527089102356943
# Change     = 0.0
# Generation = 36
# Fitness    = 12.16252713937514
# Change     = 2.635438037018197
# Generation = 37
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 38
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 39
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 40
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 41
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 42
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 43
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 44
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 45
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 46
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 47
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 48
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 49
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 50
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 51
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 52
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 53
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 54
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 55
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 56
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 57
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 58
# Fitness    = 12.16252713937514
# Change     = 0.0
# Generation = 59
# Fitness    = 19.610296762299576
# Change     = 7.447769622924437
# Generation = 60
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 61
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 62
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 63
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 64
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 65
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 66
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 67
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 68
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 69
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 70
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 71
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 72
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 73
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 74
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 75
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 76
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 77
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 78
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 79
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 80
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 81
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 82
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 83
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 84
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 85
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 86
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation = 87
# Fitness    = 19.610296762299576
# Change     = 0.0
# Generation =
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 402
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 403
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 404
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 405
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 406
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 407
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 408
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 409
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 410
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 411
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 412
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 413
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 414
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 415
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 416
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 417
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 418
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 419
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 420
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 421
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 422
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 423
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 424
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 425
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 426
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 427
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 428
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 429
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 430
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 431
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 432
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 433
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 434
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 435
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 436
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 437
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 438
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 439
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 440
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 441
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 442
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 443
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 444
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 445
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 446
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 447
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 448
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 449
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 450
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 451
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 452
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 453
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 454
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 455
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 456
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 457
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 458
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 459
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 460
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 461
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 462
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 463
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 464
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 465
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 466
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 467
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 468
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 469
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 470
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 471
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 472
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 473
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 474
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 475
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 476
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 477
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 478
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 479
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 480
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 481
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 482
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 483
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 484
# Fitness    = 22.7668881392479
# Change     = 0.0
# Generation = 485
# Fitness    = 26.81669521669925
# Change     = 4.0498070774513515
# Generation = 486
# Fitness    = 26.81669521669925
# Change     = 0.0
# Generation = 487
# Fitness    = 26.81669521669925
# Change     = 0.0
# Generation = 488
# Fitness    = 30.637765858840957
# Change     = 3.8210706421417058
# Generation = 489
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 490
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 491
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 492
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 493
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 494
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 495
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 496
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 497
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 498
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 499
# Fitness    = 30.637765858840957
# Change     = 0.0
# Generation = 500
# Fitness    = 30.637765858840957
# Change     = 0.0
# Parameters of the best solution : [-0.09346029  0.09415983  0.39008106 -0.01702712  0.61215791 -0.00212282
#   0.40659197  0.01603171  0.04625723  0.02355429  0.64557526  1.39756463]
# Fitness value of the best solution = 30.637765858840957
# Index of the best solution : 0
# Best fitness value reached after 488 generations.
# Predictions of the trained network : [array([0.17799008, 0.1775375 ]), array([1.81758269, 1.51252255])]
# Absolute error : 0.0326394556511514.

# %%
import numpy
import pygad
import pygad.nn
import pygad.gann
import pandas


def fitness_func(ga_instance, solution, sol_idx):
    global GANN_instance, data_inputs, data_outputs

    predictions = pygad.nn.predict(last_layer=GANN_instance.population_networks[sol_idx],
                                   data_inputs=data_inputs,
                                   problem_type="regression")
    solution_fitness = 1.0/numpy.mean(numpy.abs(predictions - data_outputs))

    return solution_fitness


def callback_generation(ga_instance):
    global GANN_instance, last_fitness

    population_matrices = pygad.gann.population_as_matrices(population_networks=GANN_instance.population_networks,
                                                            population_vectors=ga_instance.population)

    GANN_instance.update_population_trained_weights(
        population_trained_weights=population_matrices)

    print("Generation = {generation}".format(
        generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution(
        pop_fitness=ga_instance.last_generation_fitness)[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution(
        pop_fitness=ga_instance.last_generation_fitness)[1] - last_fitness))

    last_fitness = ga_instance.best_solution(
        pop_fitness=ga_instance.last_generation_fitness)[1].copy()


# Holds the fitness value of the previous generation.
last_fitness = 0

data = numpy.array(pandas.read_csv("../data/Fish.csv"))

# Preparing the NumPy array of the inputs.
data_inputs = numpy.asarray(data[:, 2:], dtype=numpy.float32)

# Preparing the NumPy array of the outputs.
data_outputs = numpy.asarray(data[:, 1], dtype=numpy.float32)

# The length of the input vector for each sample (i.e. number of neurons in the input layer).
num_inputs = data_inputs.shape[1]

# Creating an initial population of neural networks. 
#   The return of the initial_population() function holds references to the networks, not their weights. 
#   Using such references, the weights of all networks can be fetched.
num_solutions = 6  # A solution or a network can be used interchangeably.
GANN_instance = pygad.gann.GANN(num_solutions=num_solutions,
                                num_neurons_input=num_inputs,
                                num_neurons_hidden_layers=[2],
                                num_neurons_output=1,
                                hidden_activations=["relu"],
                                output_activation="None")

# population does not hold the numerical weights of the network instead it holds a list of references to each last layer of each network (i.e. solution) in the population. 
#   A solution or a network can be used interchangeably.
# If there is a population with 3 solutions (i.e. networks), then the population is a list with 3 elements.
#   Each element is a reference to the last layer of each network. Using such a reference, all details of the network can be accessed.
population_vectors = pygad.gann.population_as_vectors(
    population_networks=GANN_instance.population_networks)

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter.
#       This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters.
#       If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
initial_population = population_vectors.copy()

# Number of solutions to be selected as parents in the mating pool.
num_parents_mating = 4

num_generations = 500  # Number of generations.

# Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists.
mutation_percent_genes = 5

parent_selection_type = "sss"  # Type of parent selection.

crossover_type = "single_point"  # Type of the crossover operator.

mutation_type = "random"  # Type of the mutation operator.

# Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.
keep_parents = 1

init_range_low = -1
init_range_high = 1

ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       initial_population=initial_population,
                       fitness_func=fitness_func,
                       mutation_percent_genes=mutation_percent_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       keep_parents=keep_parents,
                       on_generation=callback_generation)

ga_instance.run()

# After the generations complete, some plots are showed that summarize how the outputs/fitness values evolve over generations.
ga_instance.plot_fitness()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution(
    pop_fitness=ga_instance.last_generation_fitness)
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(
    solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(
    solution_idx=solution_idx))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(
        best_solution_generation=ga_instance.best_solution_generation))

# Predicting the outputs of the data using the best solution.
predictions = pygad.nn.predict(last_layer=GANN_instance.population_networks[solution_idx],
                               data_inputs=data_inputs,
                               problem_type="regression")
print("Predictions of the trained network : {predictions}".format(
    predictions=predictions))

# Calculating some statistics
abs_error = numpy.mean(numpy.abs(predictions - data_outputs))
print("Absolute error : {abs_error}.".format(abs_error=abs_error))
# Out:
# c:\Python311\Lib\site-packages\pygad\pygad.py:748: UserWarning: The percentage of genes to mutate (mutation_percent_genes=5) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   warnings.warn(f"The percentage of genes to mutate (mutation_percent_genes={mutation_percent_genes}) resutled in selecting ({mutation_num_genes}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.")
# Generation = 1
# Fitness    = 0.0025111270159618136
# Change     = 0.0025111270159618136
# Generation = 2
# Fitness    = 0.0025125769185382384
# Change     = 1.4499025764247789e-06
# Generation = 3
# Fitness    = 0.002524205778084926
# Change     = 1.1628859546687804e-05
# Generation = 4
# Fitness    = 0.002524205778084926
# Change     = 0.0
# Generation = 5
# Fitness    = 0.002537283408386732
# Change     = 1.3077630301805768e-05
# Generation = 6
# Fitness    = 0.002548459753400226
# Change     = 1.117634501349423e-05
# Generation = 7
# Fitness    = 0.002605413924686579
# Change     = 5.695417128635284e-05
# Generation = 8
# Fitness    = 0.0026471352984692694
# Change     = 4.1721373782690335e-05
# Generation = 9
# Fitness    = 0.002652273987889097
# Change     = 5.1386894198276675e-06
# Generation = 10
# Fitness    = 0.002776985328481829
# Change     = 0.00012471134059273198
# Generation = 11
# Fitness    = 0.002776985328481829
# Change     = 0.0
# Generation = 12
# Fitness    = 0.002854519320256504
# Change     = 7.753399177467483e-05
# Generation = 13
# Fitness    = 0.0028713324660851
